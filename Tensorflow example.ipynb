# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

# %%
training_df = pd.read_csv("https://download.mlcc.google.com/mledu-datasets/california_housing_train.csv")

# %%
training_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936                66.9
# 1      1129.0       463.0         1.8200                80.1
# 2       333.0       117.0         1.6509                85.7
# 3       515.0       226.0         3.1917                73.4
# 4       624.0       262.0         1.9250                65.5

# %%
training_df["median_house_value"] /= 1000.0

# %%
training_df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  17000.000000  17000.000000        17000.000000  17000.000000
# mean    -119.562108     35.625225           28.589353   2643.664412
# std        2.005166      2.137340           12.586937   2179.947071
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.790000     33.930000           18.000000   1462.000000
# 50%     -118.490000     34.250000           29.000000   2127.000000
# 75%     -118.000000     37.720000           37.000000   3151.250000
# max     -114.310000     41.950000           52.000000  37937.000000
#
#        total_bedrooms    population    households  median_income  \
# count    17000.000000  17000.000000  17000.000000   17000.000000
# mean       539.410824   1429.573941    501.221941       3.883578
# std        421.499452   1147.852959    384.520841       1.908157
# min          1.000000      3.000000      1.000000       0.499900
# 25%        297.000000    790.000000    282.000000       2.566375
# 50%        434.000000   1167.000000    409.000000       3.544600
# 75%        648.250000   1721.000000    605.250000       4.767000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        17000.000000
# mean           207.300912
# std            115.983764
# min             14.999000
# 25%            119.400000
# 50%            180.400000
# 75%            265.000000
# max            500.001000

# %%
training_df.corr()
#the most correlated feature to median house value is median income
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925208           -0.114250     0.047010
# latitude            -0.925208  1.000000            0.016454    -0.038773
# housing_median_age  -0.114250  0.016454            1.000000    -0.360984
# total_rooms          0.047010 -0.038773           -0.360984     1.000000
# total_bedrooms       0.071802 -0.069373           -0.320434     0.928403
# population           0.101674 -0.111261           -0.295890     0.860170
# households           0.059628 -0.074902           -0.302754     0.919018
# median_income       -0.015485 -0.080303           -0.115932     0.195383
# median_house_value  -0.044982 -0.144917            0.106758     0.130991
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.071802    0.101674    0.059628      -0.015485
# latitude                 -0.069373   -0.111261   -0.074902      -0.080303
# housing_median_age       -0.320434   -0.295890   -0.302754      -0.115932
# total_rooms               0.928403    0.860170    0.919018       0.195383
# total_bedrooms            1.000000    0.881169    0.980920      -0.013495
# population                0.881169    1.000000    0.909247      -0.000638
# households                0.980920    0.909247    1.000000       0.007644
# median_income            -0.013495   -0.000638    0.007644       1.000000
# median_house_value        0.045783   -0.027850    0.061031       0.691871
#
#                     median_house_value
# longitude                    -0.044982
# latitude                     -0.144917
# housing_median_age            0.106758
# total_rooms                   0.130991
# total_bedrooms                0.045783
# population                   -0.027850
# households                    0.061031
# median_income                 0.691871
# median_house_value            1.000000

# %%
def build_model(my_learning_rate):
    """Create and compile a simple linear regression model."""
    # Most simple tf.keras models are sequential.
    model = tf.keras.models.Sequential()
    # Describe the topography of the model.
    model.add(tf.keras.layers.Dense(units=1, 
                                  input_shape=(1,)))
    # Compile the model topography into code that TensorFlow can efficiently execute. Configure training to minimize the model's mean squared error. 
    model.compile(optimizer=tf.keras.optimizers.RMSprop(lr=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])
    return model

def train_model(model, df, feature, label, epochs, batch_size):
  """Train the model by feeding it data."""

  # Feed the model the feature and the label.
  # The model will train for the specified number of epochs. 
  history = model.fit(x=df[feature],
                      y=df[label],
                      batch_size=batch_size,
                      epochs=epochs)

  # Gather the trained model's weight and bias.
  trained_weight = model.get_weights()[0]
  trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the rest of history.
  epochs = history.epoch
  
  # Isolate the error for each epoch.
  hist = pd.DataFrame(history.history)

  # To track the progression of training, we're going to take a snapshot
  # of the model's root mean squared error at each epoch. 
  rmse = hist["root_mean_squared_error"]

  return trained_weight, trained_bias, epochs, rmse

print("Defined the create_model and traing_model functions.")
# Out:
# Defined the create_model and traing_model functions.

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against 200 random training examples."""

  # Label the axes.
  plt.xlabel(feature)
  plt.ylabel(label)

  # Create a scatter plot from 200 random points of the dataset.
  random_examples = training_df.sample(n=200)
  plt.scatter(random_examples[feature], random_examples[label])

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = 10000
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()


def plot_the_loss_curve(epochs, rmse):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([rmse.min()*0.97, rmse.max()])
  plt.show()  

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %%
# The following variables are the hyperparameters.
learning_rate = 0.01
epochs = 30
batch_size = 30

# Specify the feature and the label.
my_feature = "median_income"  # the total number of rooms on a specific city block.
my_label="median_house_value" # the median value of a house on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on total_rooms.  

# Discard any pre-existing version of the model.
my_model = None

# Invoke the functions.
my_model = build_model(learning_rate)
weight, bias, epochs, rmse = train_model(my_model, training_df, 
                                         my_feature, my_label,
                                         epochs, batch_size)

print("\nThe learned weight for your model is %.4f" % weight)
print("The learned bias for your model is %.4f\n" % bias )

plot_the_model(weight, bias, my_feature, my_label)
plot_the_loss_curve(epochs, rmse)
# Out:
# Train on 17000 samples
# Epoch 1/30
# 17000/17000 [==============================] - 2s 125us/sample - loss: 48107.4924 - root_mean_squared_error: 219.3342
# Epoch 2/30
# 17000/17000 [==============================] - 1s 79us/sample - loss: 37128.9817 - root_mean_squared_error: 192.6888
# Epoch 3/30
# 17000/17000 [==============================] - 1s 78us/sample - loss: 27901.9560 - root_mean_squared_error: 167.0388
# Epoch 4/30
# 17000/17000 [==============================] - 1s 76us/sample - loss: 20383.2466 - root_mean_squared_error: 142.7699
# Epoch 5/30
# 17000/17000 [==============================] - 1s 79us/sample - loss: 14543.3813 - root_mean_squared_error: 120.5960
# Epoch 6/30
# 17000/17000 [==============================] - 1s 75us/sample - loss: 10429.1770 - root_mean_squared_error: 102.1234
# Epoch 7/30
# 17000/17000 [==============================] - 1s 77us/sample - loss: 8028.2765 - root_mean_squared_error: 89.6007
# Epoch 8/30
# 17000/17000 [==============================] - 1s 77us/sample - loss: 7137.5310 - root_mean_squared_error: 84.4839
# Epoch 9/30
# 17000/17000 [==============================] - 1s 77us/sample - loss: 7018.0046 - root_mean_squared_error: 83.7735
# Epoch 10/30
# 17000/17000 [==============================] - 1s 73us/sample - loss: 7013.9986 - root_mean_squared_error: 83.7496
# Epoch 11/30
# 17000/17000 [==============================] - 1s 80us/sample - loss: 7013.5659 - root_mean_squared_error: 83.7470
# Epoch 12/30
# 17000/17000 [==============================] - 2s 94us/sample - loss: 7013.9540 - root_mean_squared_error: 83.7493
# Epoch 13/30
# 17000/17000 [==============================] - 2s 92us/sample - loss: 7013.6007 - root_mean_squared_error: 83.7472
# Epoch 14/30
# 17000/17000 [==============================] - 1s 84us/sample - loss: 7013.7417 - root_mean_squared_error: 83.7481
# Epoch 15/30
# 17000/17000 [==============================] - 1s 77us/sample - loss: 7013.7367 - root_mean_squared_error: 83.7481
# Epoch 16/30
# 17000/17000 [==============================] - 1s 78us/sample - loss: 7013.8457 - root_mean_squared_error: 83.7487
# Epoch 17/30
# 17000/17000 [==============================] - 1s 76us/sample - loss: 7013.6556 - root_mean_squared_error: 83.7476
# Epoch 18/30
# 17000/17000 [==============================] - 1s 79us/sample - loss: 7013.8052 - root_mean_squared_error: 83.7485
# Epoch 19/30
# 17000/17000 [==============================] - 1s 82us/sample - loss: 7013.6423 - root_mean_squared_error: 83.7475
# Epoch 20/30
# 17000/17000 [==============================] - 1s 79us/sample - loss: 7013.4593 - root_mean_squared_error: 83.7464
# Epoch 21/30
# 17000/17000 [==============================] - 1s 85us/sample - loss: 7013.8741 - root_mean_squared_error: 83.7489
# Epoch 22/30
# 17000/17000 [==============================] - 1s 82us/sample - loss: 7013.5163 - root_mean_squared_error: 83.7467
# Epoch 23/30
# 17000/17000 [==============================] - ETA: 0s - loss: 7007.4579 - root_mean_squared_error: 83.710 - 1s 85us/sample - loss: 7013.5067 - root_mean_squared_error: 83.7467
# Epoch 24/30
# 17000/17000 [==============================] - 2s 89us/sample - loss: 7013.5408 - root_mean_squared_error: 83.7469
# Epoch 25/30
# 17000/17000 [==============================] - 1s 79us/sample - loss: 7013.6219 - root_mean_squared_error: 83.7474
# Epoch 26/30
# 17000/17000 [==============================] - 1s 79us/sample - loss: 7013.6492 - root_mean_squared_error: 83.7475
# Epoch 27/30
# 17000/17000 [==============================] - 1s 81us/sample - loss: 7013.5681 - root_mean_squared_error: 83.7470
# Epoch 28/30
# 17000/17000 [==============================] - 1s 76us/sample - loss: 7013.6013 - root_mean_squared_error: 83.7472
# Epoch 29/30
# 17000/17000 [==============================] - 1s 80us/sample - loss: 7013.4899 - root_mean_squared_error: 83.7466
# Epoch 30/30
# 17000/17000 [==============================] - 1s 81us/sample - loss: 7013.5803 - root_mean_squared_error: 83.7471
#
# The learned weight for your model is 42.3047
# The learned bias for your model is 42.6067
# C:\Users\Dips\.conda\envs\TensorFlow\lib\site-packages\numpy\core\_asarray.py:136: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order, subok=True)

# %%
def predict_house_values(n, feature, label):
  """Predict house values based on a feature."""

  batch = training_df[feature][10000:10000 + n]
  predicted_values = my_model.predict_on_batch(x=batch)

  print("feature   label          predicted")
  print("  value   value          value")
  print("          in thousand$   in thousand$")
  print("--------------------------------------")
  for i in range(n):
    print ("%5.0f %6.0f %15.0f" % (training_df[feature][10000 + i],
                                   training_df[label][10000 + i],
                                   predicted_values[i][0] ))

# %%
predict_house_values(10, my_feature, my_label)
# Out:
# feature   label          predicted
#   value   value          value
#           in thousand$   in thousand$
# --------------------------------------
#     2     53             134
#     4     92             212
#     3     69             154
#     2     62             132
#     3     80             153
#     2    295             147
#    10    500             456
#     5    342             260
#     2    118             146
#     4    128             221

# %%
training_df["rooms_per_person"] = training_df["total_rooms"] / training_df["population"]

# %%
training_df.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.925208           -0.114250     0.047010
# latitude            -0.925208  1.000000            0.016454    -0.038773
# housing_median_age  -0.114250  0.016454            1.000000    -0.360984
# total_rooms          0.047010 -0.038773           -0.360984     1.000000
# total_bedrooms       0.071802 -0.069373           -0.320434     0.928403
# population           0.101674 -0.111261           -0.295890     0.860170
# households           0.059628 -0.074902           -0.302754     0.919018
# median_income       -0.015485 -0.080303           -0.115932     0.195383
# median_house_value  -0.044982 -0.144917            0.106758     0.130991
# rooms_per_person    -0.077773  0.143017           -0.103655     0.121001
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.071802    0.101674    0.059628      -0.015485
# latitude                 -0.069373   -0.111261   -0.074902      -0.080303
# housing_median_age       -0.320434   -0.295890   -0.302754      -0.115932
# total_rooms               0.928403    0.860170    0.919018       0.195383
# total_bedrooms            1.000000    0.881169    0.980920      -0.013495
# population                0.881169    1.000000    0.909247      -0.000638
# households                0.980920    0.909247    1.000000       0.007644
# median_income            -0.013495   -0.000638    0.007644       1.000000
# median_house_value        0.045783   -0.027850    0.061031       0.691871
# rooms_per_person          0.047811   -0.140277   -0.034049       0.232667
#
#                     median_house_value  rooms_per_person
# longitude                    -0.044982         -0.077773
# latitude                     -0.144917          0.143017
# housing_median_age            0.106758         -0.103655
# total_rooms                   0.130991          0.121001
# total_bedrooms                0.045783          0.047811
# population                   -0.027850         -0.140277
# households                    0.061031         -0.034049
# median_income                 0.691871          0.232667
# median_house_value            1.000000          0.206969
# rooms_per_person              0.206969          1.000000

# %%
#rooms per person is better correlated than total_rooms and population but still not as correalted as median_income.
#Lets see if number of bedrooms per household is better correlated
training_df["rooms_per_household"] = training_df["total_rooms"] / training_df["households"]
training_df.corr()
# Out:
#                         longitude  latitude  housing_median_age  total_rooms  \
# longitude                1.000000 -0.925208           -0.114250     0.047010
# latitude                -0.925208  1.000000            0.016454    -0.038773
# housing_median_age      -0.114250  0.016454            1.000000    -0.360984
# total_rooms              0.047010 -0.038773           -0.360984     1.000000
# total_bedrooms           0.071802 -0.069373           -0.320434     0.928403
# population               0.101674 -0.111261           -0.295890     0.860170
# households               0.059628 -0.074902           -0.302754     0.919018
# median_income           -0.015485 -0.080303           -0.115932     0.195383
# median_house_value      -0.044982 -0.144917            0.106758     0.130991
# rooms_per_person        -0.077773  0.143017           -0.103655     0.121001
# bedrooms_per_household   0.008413  0.073101           -0.074101     0.024485
# rooms_per_household     -0.032894  0.110017           -0.146234     0.125385
#
#                         total_bedrooms  population  households  median_income  \
# longitude                     0.071802    0.101674    0.059628      -0.015485
# latitude                     -0.069373   -0.111261   -0.074902      -0.080303
# housing_median_age           -0.320434   -0.295890   -0.302754      -0.115932
# total_rooms                   0.928403    0.860170    0.919018       0.195383
# total_bedrooms                1.000000    0.881169    0.980920      -0.013495
# population                    0.881169    1.000000    0.909247      -0.000638
# households                    0.980920    0.909247    1.000000       0.007644
# median_income                -0.013495   -0.000638    0.007644       1.000000
# median_house_value            0.045783   -0.027850    0.061031       0.691871
# rooms_per_person              0.047811   -0.140277   -0.034049       0.232667
# bedrooms_per_household        0.040284   -0.066444   -0.056213      -0.062500
# rooms_per_household          -0.006480   -0.074806   -0.084505       0.317311
#
#                         median_house_value  rooms_per_person  \
# longitude                        -0.044982         -0.077773
# latitude                         -0.144917          0.143017
# housing_median_age                0.106758         -0.103655
# total_rooms                       0.130991          0.121001
# total_bedrooms                    0.045783          0.047811
# population                       -0.027850         -0.140277
# households                        0.061031         -0.034049
# median_income                     0.691871          0.232667
# median_house_value                1.000000          0.206969
# rooms_per_person                  0.206969          1.000000
# bedrooms_per_household           -0.045668          0.827689
# rooms_per_household               0.150081          0.888227
#
#                         bedrooms_per_household  rooms_per_household
# longitude                             0.008413            -0.032894
# latitude                              0.073101             0.110017
# housing_median_age                   -0.074101            -0.146234
# total_rooms                           0.024485             0.125385
# total_bedrooms                        0.040284            -0.006480
# population                           -0.066444            -0.074806
# households                           -0.056213            -0.084505
# median_income                        -0.062500             0.317311
# median_house_value                   -0.045668             0.150081
# rooms_per_person                      0.827689             0.888227
# bedrooms_per_household                1.000000             0.853618
# rooms_per_household                   0.853618             1.000000
